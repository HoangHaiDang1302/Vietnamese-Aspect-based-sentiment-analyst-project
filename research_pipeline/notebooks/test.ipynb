# %%
import numpy as np
import pandas as pd

text = "AI hỗ trợ học tập"
tokens = text.split()
scores = np.array([0.1, 0.7, 0.2, 0.4,0.5])
df = pd.DataFrame({'token': tokens, 'score': scores})
print(df)
# Out:
#   token  score
# 0    AI    0.1
# 1    hỗ    0.7
# 2   trợ    0.2
# 3   học    0.4
# 4   tập    0.5
