# %% [markdown]
# # [Kaggle] Pipeline: ATE + ASC & Full Evaluation
# Can chay NB01 va NB02 truoc de co models.
#
# **Evaluation**:
# - Span-Level Exact Match F1 (nghiem ngat)
# - Sentence-Level Multi-Label F1 (giong `phobert-crf-absa.ipynb`)

# %% [markdown]
# ## 0. Setup

# %%
import subprocess, sys, os

subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q',
                       'underthesea', 'pytorch-crf', 'gensim'])

DATA_DATASET = "UIT-ViSD4SA"
SRC_DATASET  = "absa-src"

IS_KAGGLE = os.path.exists('/kaggle/input')
if IS_KAGGLE:
    DATA_DIR = '/kaggle/input/datasets/danghoang1302/uit-visd4sa'
    SAVE_DIR = '/kaggle/working/results'
    SRC_INPUT = '/kaggle/input/datasets/danghoang1302/absa-src'
    os.system(f'cp -r {SRC_INPUT}/src /kaggle/working/src')
    sys.path.insert(0, '/kaggle/working')
    print(f"KAGGLE | Data: {DATA_DIR}")
else:
    sys.path.insert(0, os.path.abspath(".."))
    DATA_DIR = os.path.join("..", "..", "data")
    SAVE_DIR = os.path.join("..", "..", "results")
    print(f"LOCAL mode")

for fn in ['train.jsonl', 'dev.jsonl', 'test.jsonl']:
    assert os.path.exists(os.path.join(DATA_DIR, fn)), f"MISSING: {fn}"
print("All data files OK!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 72.0 MB/s eta 0:00:00
# KAGGLE | Data: /kaggle/input/datasets/danghoang1302/uit-visd4sa
# All data files OK!

# %% [markdown]
# ## 1. Imports & Load Models

# %%
import torch, torch.nn as nn, numpy as np, pandas as pd
from torch.utils.data import DataLoader
from IPython.display import display

from src.utils.preprocess import (load_raw_data, segment_items, build_vocab,
                                  train_w2v_embeddings, tokenize_baseline)
from src.ate.ate_dataset import ATEDataset, BIO_TAGS, TAG2ID, NUM_TAGS, ASPECTS
from src.ate.ate_model import build_ate_model
from src.asc.asc_model import build_asc_model
from src.utils.metrics import (bio_tags_to_spans, evaluate_spans_f1,
                               char_spans_to_word_spans,
                               bio_to_sentence_labels, evaluate_multilabel)
from src.utils.visualization import plot_error_analysis

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

print("Building vocab & embeddings from scratch...")
train_items = segment_items(load_raw_data(os.path.join(DATA_DIR, "train.jsonl")))
dev_items = segment_items(load_raw_data(os.path.join(DATA_DIR, "dev.jsonl")))
test_items = segment_items(load_raw_data(os.path.join(DATA_DIR, "test.jsonl")))

all_texts = [item["text"] for item in train_items + dev_items + test_items]
word2idx = build_vocab(all_texts, min_freq=2, special_tokens=["[ASP]"])
VOCAB_SIZE = len(word2idx)
EMB_DIM = 150
emb_matrix = train_w2v_embeddings(all_texts, word2idx, emb_dim=EMB_DIM)
print(f"Vocab: {VOCAB_SIZE} | Emb: {EMB_DIM}d")

MODELS_DIR = "/kaggle/input/datasets/danghoang1302/models"
best_ate = "BiLSTM-CRF"
best_asc = "BiGRU"

try:
    print(f"Loading ATE: {best_ate} | ASC: {best_asc} tu {MODELS_DIR}")
    ate_type = best_ate.replace("-CRF", "")
    ate_model = build_ate_model(model_type=ate_type, vocab_size=VOCAB_SIZE, emb_dim=EMB_DIM,
        hidden_dim=256, num_tags=NUM_TAGS, n_layers=2, dropout=0.3).to(device)
    ate_model.load_state_dict(torch.load(os.path.join(MODELS_DIR, f"best_ate_{best_ate}.pt"), map_location=device))
    ate_model.eval()

    asc_model = build_asc_model(model_type=best_asc, vocab_size=VOCAB_SIZE, emb_dim=EMB_DIM,
        hidden_dim=256, num_classes=3, n_layers=2, dropout=0.3).to(device)
    asc_model.load_state_dict(torch.load(os.path.join(MODELS_DIR, f"best_asc_{best_asc}.pt"), map_location=device))
    asc_model.eval()
    print("Models loaded successfully!")
except Exception as e:
    print(f"Loi load model: {e}")
# Out:
# Device: cuda
# Building vocab & embeddings from scratch...
# Training Word2Vec 150d...
# Embedding Matrix ready. Hit: 6166/6169 (100.0%)
# Vocab: 6169 | Emb: 150d
# Loading ATE: BiLSTM-CRF | ASC: BiGRU tu /kaggle/input/datasets/danghoang1302/models
# Models loaded successfully!

# %% [markdown]
# ## 2. Pipeline Inference & Evaluation

# %%
MAX_LEN = 128
SENTIMENT_NAMES = {0: "POSITIVE", 1: "NEGATIVE", 2: "NEUTRAL"}
LABEL_NAMES = [f"{a}#{s}" for a in ASPECTS for s in ["POSITIVE","NEUTRAL","NEGATIVE"]]

def pipeline_predict(text, ate_model, asc_model, word2idx, device):
    """Pipeline: ATE -> ASC. Returns list of (combined_label, start_word, end_word)."""
    words = text.split()[:MAX_LEN]
    seq, length = tokenize_baseline(text, word2idx, MAX_LEN)
    seq_t = torch.tensor([seq], dtype=torch.long).to(device)
    mask_t = torch.zeros(1, MAX_LEN, dtype=torch.bool); mask_t[0, :length] = True
    mask_t = mask_t.to(device); lens_t = torch.tensor([length])

    with torch.no_grad():
        pred_tags = ate_model(seq_t, mask=mask_t, lens=lens_t)[0]
    spans = bio_tags_to_spans(pred_tags, BIO_TAGS, length)

    results = []
    for aspect_label, start_idx, end_idx in spans:
        aspect_text = " ".join(words[start_idx:end_idx])
        marked = " ".join(words[:start_idx]) + " [ASP] " + aspect_text + " [ASP] " + " ".join(words[end_idx:])
        asc_seq, _ = tokenize_baseline(marked.strip(), word2idx, MAX_LEN)
        asc_t = torch.tensor([asc_seq], dtype=torch.long).to(device)
        with torch.no_grad():
            sentiment_id = asc_model(asc_t).argmax(dim=1).item()
        combined = f"{aspect_label}#{SENTIMENT_NAMES[sentiment_id]}"
        results.append((combined, start_idx, end_idx))
    return results

# === Full test set ===
print("Running pipeline on test set...")
all_true, all_pred = [], []
for item in test_items:
    true_spans = char_spans_to_word_spans(item["text"], item.get("labels", []), MAX_LEN)
    pred_spans = pipeline_predict(item["text"], ate_model, asc_model, word2idx, device)
    all_true.append(true_spans)
    all_pred.append(pred_spans)

# METRIC 1: Span-Level
span_res = evaluate_spans_f1(all_pred, all_true)
print(f"\n{'='*60}")
print(f"  METRIC 1: Span-Level Exact Match")
print(f"{'='*60}")
print(f"  P={span_res['precision']:.4f}  R={span_res['recall']:.4f}  F1={span_res['f1']:.4f}")
print(f"  (TP={span_res['tp']}, FP={span_res['fp']}, FN={span_res['fn']})")

# METRIC 2: Sentence-Level Multi-Label
label2id = {ln: i for i, ln in enumerate(LABEL_NAMES)}
num_labels = len(LABEL_NAMES)
true_sent, pred_sent = [], []
for ts, ps in zip(all_true, all_pred):
    tv = [0]*num_labels
    for l,_,_ in ts:
        if l in label2id: tv[label2id[l]] = 1
    pv = [0]*num_labels
    for l,_,_ in ps:
        if l in label2id: pv[label2id[l]] = 1
    true_sent.append(tv); pred_sent.append(pv)
mt = evaluate_multilabel(true_sent, pred_sent, LABEL_NAMES)

print(f"\n{'='*60}")
print(f"  METRIC 2: Sentence-Level Multi-Label")
print(f"{'='*60}")
for avg in ['micro','macro','weighted']:
    m = mt[avg]
    print(f"  {avg:<12} P={m['precision']:.4f}  R={m['recall']:.4f}  F1={m['f1']:.4f}")
print(f"\n  {'Label':<25} {'P':>7} {'R':>7} {'F1':>7} {'Sup':>6}")
print(f"  {'-'*55}")
for ln in LABEL_NAMES:
    m = mt[ln]
    print(f"  {ln:<25} {m['precision']:>7.4f} {m['recall']:>7.4f} {m['f1']:>7.4f} {m['support']:>6d}")
# Out:
# Running pipeline on test set...
#
# ============================================================
#   METRIC 1: Span-Level Exact Match
# ============================================================
#   P=0.3962  R=0.3500  F1=0.3716
#   (TP=2453, FP=3739, FN=4556)
#
# ============================================================
#   METRIC 2: Sentence-Level Multi-Label
# ============================================================
#   micro        P=0.8221  R=0.7467  F1=0.7826
#   macro        P=0.6522  R=0.6156  F1=0.6190
#   weighted     P=0.8358  R=0.7467  F1=0.7867
#
#   Label                           P       R      F1    Sup
#   -------------------------------------------------------
#   CAMERA#POSITIVE            0.9238  0.8064  0.8611    346
#   CAMERA#NEUTRAL             0.6203  0.6533  0.6364     75
#   CAMERA#NEGATIVE            0.8144  0.7816  0.7977    174
#   FEATURES#POSITIVE          0.8333  0.6875  0.7534    240
#   FEATURES#NEUTRAL           0.3220  0.5938  0.4176     32
#   FEATURES#NEGATIVE          0.8733  0.7751  0.8212    489
#   PERFORMANCE#POSITIVE       0.9022  0.7896  0.8421    689
#   PERFORMANCE#NEUTRAL        0.2815  0.4935  0.3585     77
#   PERFORMANCE#NEGATIVE       0.7892  0.7294  0.7582    462
#   DESIGN#POSITIVE            0.9225  0.8623  0.8914    276
#   DESIGN#NEUTRAL             0.3529  0.4000  0.3750     15
#   DESIGN#NEGATIVE            0.6757  0.5263  0.5917     95
#   PRICE#POSITIVE             0.5929  0.5537  0.5726    121
#   PRICE#NEUTRAL              0.4314  0.3438  0.3826     64
#   PRICE#NEGATIVE             0.6250  0.3623  0.4587     69
#   GENERAL#POSITIVE           0.9223  0.8252  0.8710   1064
#   GENERAL#NEUTRAL            0.5692  0.5873  0.5781     63
#   GENERAL#NEGATIVE           0.7326  0.5880  0.6524    233
#   SCREEN#POSITIVE            0.8705  0.7707  0.8176    157
#   SCREEN#NEUTRAL             0.3636  0.4444  0.4000      9
#   SCREEN#NEGATIVE            0.7439  0.6162  0.6740     99
#   BATTERY#POSITIVE           0.9328  0.8292  0.8780    603
#   BATTERY#NEUTRAL            0.3727  0.5942  0.4581     69
#   BATTERY#NEGATIVE           0.8875  0.7340  0.8035    376
#   STORAGE#POSITIVE           0.6429  0.6000  0.6207     15
#   STORAGE#NEUTRAL            0.0000  0.0000  0.0000      7
#   STORAGE#NEGATIVE           1.0000  0.5833  0.7368     12
#   SER&ACC#POSITIVE           0.8928  0.8325  0.8616    400
#   SER&ACC#NEUTRAL            0.1250  0.6667  0.2105      3
#   SER&ACC#NEGATIVE           0.5513  0.4388  0.4886     98

# %% [markdown]
# ## 3. Demo: Test Predictions
# Xem dau ra cua Pipeline tren 10 cau test.

# %%
import random
random.seed(42)
sample_indices = random.sample(range(len(test_items)), min(10, len(test_items)))

print(f"{'='*70}")
print(f"  PIPELINE DEMO: 10 cau test ngau nhien")
print(f"{'='*70}")

for idx in sample_indices:
    item = test_items[idx]
    text = item["text"]
    words = text.split()[:MAX_LEN]

    true_spans = all_true[idx]
    pred_spans = all_pred[idx]
    true_set = set(true_spans)
    pred_set = set(pred_spans)

    tp = true_set & pred_set
    fp = pred_set - true_set
    fn = true_set - pred_set

    print(f"\n{'─'*70}")
    print(f"  [{idx}] {text[:100]}{'...' if len(text)>100 else ''}")
    print(f"  TRUE ({len(true_spans)}):")
    for label, s, e in true_spans:
        aspect_text = ' '.join(words[s:e]) if e <= len(words) else '?'
        match = '✅' if (label, s, e) in pred_set else '❌ MISSED'
        print(f"    {label:<30} [{s}:{e}] \"{aspect_text}\"  {match}")

    print(f"  PRED ({len(pred_spans)}):")
    for label, s, e in pred_spans:
        aspect_text = ' '.join(words[s:e]) if e <= len(words) else '?'
        match = '✅' if (label, s, e) in true_set else '❌ WRONG'
        print(f"    {label:<30} [{s}:{e}] \"{aspect_text}\"  {match}")

    if not pred_spans:
        print(f"    (khong co prediction)")

print(f"\n{'='*70}")
print(f"  Tong: TP={len(tp)} correct, FP={len(fp)} wrong, FN={len(fn)} missed")
# Out:
# ======================================================================
#   PIPELINE DEMO: 10 cau test ngau nhien
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
#   [456] sản_phẩm sài tốt game mượt , hoàn_hảo chưa có vấn_đề gì . nhân_viên phục_vụ rất tốt_👍 👍_😄 😄
#   TRUE (4):
#     GENERAL#POSITIVE               [0:3] "sản_phẩm sài tốt"  ✅
#     PERFORMANCE#POSITIVE           [3:5] "game mượt"  ✅
#     GENERAL#POSITIVE               [6:11] "hoàn_hảo chưa có vấn_đề gì"  ✅
#     SER&ACC#POSITIVE               [11:16] ". nhân_viên phục_vụ rất tốt_👍"  ❌ MISSED
#   PRED (4):
#     GENERAL#POSITIVE               [0:3] "sản_phẩm sài tốt"  ✅
#     PERFORMANCE#POSITIVE           [3:5] "game mượt"  ✅
#     GENERAL#POSITIVE               [6:11] "hoàn_hảo chưa có vấn_đề gì"  ✅
#     SER&ACC#POSITIVE               [11:17] ". nhân_viên phục_vụ rất tốt_👍 👍_😄"  ❌ WRONG
#
# ──────────────────────────────────────────────────────────────────────
#   [102] sau hơn một tháng sử_dụng mình đánh_giá tất_cả mọi thứ ok_nha , không biết sao nhiều người nói nhiều...
#   TRUE (1):
#     GENERAL#POSITIVE               [5:11] "mình đánh_giá tất_cả mọi thứ ok_nha"  ❌ MISSED
#   PRED (1):
#     GENERAL#POSITIVE               [7:11] "tất_cả mọi thứ ok_nha"  ❌ WRONG
#
# ──────────────────────────────────────────────────────────────────────
#   [1126] máy sài rất oke . chơi game mượt không lag . lướt_web nhanh đã mua được 2 tháng không thấy có gì bất...
#   TRUE (3):
#     GENERAL#POSITIVE               [0:4] "máy sài rất oke"  ✅
#     PERFORMANCE#POSITIVE           [5:13] "chơi game mượt không lag . lướt_web nhanh"  ❌ MISSED
#     GENERAL#POSITIVE               [18:32] "không thấy có gì bất_thườngtrong tầm giá này là được rồi không đòi_hỏi thêm"  ❌ MISSED
#   PRED (3):
#     GENERAL#POSITIVE               [0:4] "máy sài rất oke"  ✅
#     PERFORMANCE#POSITIVE           [5:10] "chơi game mượt không lag"  ❌ WRONG
#     BATTERY#POSITIVE               [10:13] ". lướt_web nhanh"  ❌ WRONG
#
# ──────────────────────────────────────────────────────────────────────
#   [1003] máy bị đơ màn_hình khi chơi pubg_va liên_quân cho hoi xin doi_may dc ko con moi thu deu on xai ok
#   TRUE (2):
#     PERFORMANCE#NEGATIVE           [0:8] "máy bị đơ màn_hình khi chơi pubg_va liên_quân"  ✅
#     GENERAL#POSITIVE               [15:21] "moi thu deu on xai ok"  ✅
#   PRED (2):
#     PERFORMANCE#NEGATIVE           [0:8] "máy bị đơ màn_hình khi chơi pubg_va liên_quân"  ✅
#     GENERAL#POSITIVE               [15:21] "moi thu deu on xai ok"  ✅
#
# ──────────────────────────────────────────────────────────────────────
#   [914] pin không khỏe bằng oppo a3s 4000 mahcamera thường_xuyên lỗi . chụp ảnh phóng lên bị vỡ quá nhiềusai...
#   TRUE (3):
#     BATTERY#NEGATIVE               [0:8] "pin không khỏe bằng oppo a3s 4000 mahcamera"  ❌ MISSED
#     CAMERA#NEGATIVE                [7:19] "mahcamera thường_xuyên lỗi . chụp ảnh phóng lên bị vỡ quá nhiềusai_lầm"  ❌ MISSED
#     GENERAL#NEGATIVE               [18:23] "nhiềusai_lầm khi chọn mua sản_phẩm"  ❌ MISSED
#   PRED (2):
#     BATTERY#NEGATIVE               [0:10] "pin không khỏe bằng oppo a3s 4000 mahcamera thường_xuyên lỗi"  ❌ WRONG
#     CAMERA#NEGATIVE                [10:23] ". chụp ảnh phóng lên bị vỡ quá nhiềusai_lầm khi chọn mua sản_phẩm"  ❌ WRONG
#
# ──────────────────────────────────────────────────────────────────────
#   [571] pin tụt nhanh hơn so với các máy androi khác chung tầm dung_lượng . lâu_lâu xảy ra tình_trạng đơ máy...
#   TRUE (4):
#     BATTERY#NEGATIVE               [0:13] "pin tụt nhanh hơn so với các máy androi khác chung tầm dung_lượng"  ❌ MISSED
#     PERFORMANCE#NEGATIVE           [15:28] "xảy ra tình_trạng đơ máy khi dùng ứng_dụng ( dù nhẹ hay nặng"  ❌ MISSED
#     FEATURES#NEGATIVE              [29:39] ". bluetooth cực_tệ trong việc kết_nối phát_nhạc , rất chập_chờn"  ❌ MISSED
#     CAMERA#NEGATIVE                [51:70] ". ) . cam trước khi call_video hoặc chụp hình chỗ thiếu sáng chút là tệ hẳn về chất_lượng"  ❌ MISSED
#   PRED (4):
#     BATTERY#NEGATIVE               [0:3] "pin tụt nhanh"  ❌ WRONG
#     PERFORMANCE#NEGATIVE           [14:23] "lâu_lâu xảy ra tình_trạng đơ máy khi dùng ứng_dụng"  ❌ WRONG
#     FEATURES#NEGATIVE              [28:39] ") . bluetooth cực_tệ trong việc kết_nối phát_nhạc , rất chập_chờn"  ❌ WRONG
#     CAMERA#NEGATIVE                [50:69] "hơn . ) . cam trước khi call_video hoặc chụp hình chỗ thiếu sáng chút là tệ hẳn về"  ❌ WRONG
#
# ──────────────────────────────────────────────────────────────────────
#   [419] có ghi_âm cuộc_gọi không shop . vì mình dùng y9 không có nên muốn đổi sang máy khác
#   TRUE (0):
#   PRED (1):
#     FEATURES#NEGATIVE              [0:5] "có ghi_âm cuộc_gọi không shop"  ❌ WRONG
#
# ──────────────────────────────────────────────────────────────────────
#   [356] máy rất ổn trong tầm_giá này . pubg bao_mượt . pin trâu . màn_hình tạm ổn . sạc nhanh
#   TRUE (5):
#     GENERAL#POSITIVE               [0:3] "máy rất ổn"  ✅
#     PERFORMANCE#POSITIVE           [7:9] "pubg bao_mượt"  ✅
#     BATTERY#POSITIVE               [10:12] "pin trâu"  ❌ MISSED
#     SCREEN#NEUTRAL                 [13:16] "màn_hình tạm ổn"  ❌ MISSED
#     BATTERY#POSITIVE               [17:19] "sạc nhanh"  ❌ MISSED
#   PRED (5):
#     GENERAL#POSITIVE               [0:3] "máy rất ổn"  ✅
#     PERFORMANCE#POSITIVE           [7:9] "pubg bao_mượt"  ✅
#     BATTERY#POSITIVE               [9:12] ". pin trâu"  ❌ WRONG
#     SCREEN#NEUTRAL                 [12:15] ". màn_hình tạm"  ❌ WRONG
#     BATTERY#POSITIVE               [15:19] "ổn . sạc nhanh"  ❌ WRONG
#
# ──────────────────────────────────────────────────────────────────────
#   [1728] sản_phẩm tốt , pin trâu chơi game mượt_nhẹ , hệ_hành tốt , nhân_viên tư_vấn nhiệt_tìnhđã sử_dụng tro...
#   TRUE (5):
#     GENERAL#POSITIVE               [0:2] "sản_phẩm tốt"  ✅
#     BATTERY#POSITIVE               [3:5] "pin trâu"  ✅
#     PERFORMANCE#POSITIVE           [5:11] "chơi game mượt_nhẹ , hệ_hành tốt"  ❌ MISSED
#     SER&ACC#POSITIVE               [11:15] ", nhân_viên tư_vấn nhiệt_tìnhđã"  ❌ MISSED
#     GENERAL#POSITIVE               [19:21] "ngày rất"  ❌ MISSED
#   PRED (4):
#     GENERAL#POSITIVE               [0:2] "sản_phẩm tốt"  ✅
#     BATTERY#POSITIVE               [3:5] "pin trâu"  ✅
#     PERFORMANCE#POSITIVE           [5:10] "chơi game mượt_nhẹ , hệ_hành"  ❌ WRONG
#     SER&ACC#POSITIVE               [10:21] "tốt , nhân_viên tư_vấn nhiệt_tìnhđã sử_dụng trong vòng 3 ngày rất"  ❌ WRONG
#
# ──────────────────────────────────────────────────────────────────────
#   [130] máy có cấu_hình thấp so với các máy khác trong tầm_giá !_nhưng nếu không chơi game thì các tác_vụ bì...
#   TRUE (4):
#     PERFORMANCE#NEGATIVE           [0:11] "máy có cấu_hình thấp so với các máy khác trong tầm_giá"  ❌ MISSED
#     PERFORMANCE#POSITIVE           [19:27] "bình_thường rất ok . nếu so với ss_a20s"  ❌ MISSED
#     GENERAL#POSITIVE               [34:41] "nhiều và cũng rẻ hơn_nữa . tóm_lại"  ❌ MISSED
#     PRICE#POSITIVE                 [41:45] "nếu anh_em chưa xài"  ❌ MISSED
#   PRED (3):
#     PERFORMANCE#NEUTRAL            [0:22] "máy có cấu_hình thấp so với các máy khác trong tầm_giá !_nhưng nếu không chơi game thì các tác_vụ bình_thường rất ok"  ❌ WRONG
#     PERFORMANCE#POSITIVE           [62:73] "đâu , điện_thoại ngoài cấu_hình ra thì còn nhiều cái hay"  ❌ WRONG
#     GENERAL#POSITIVE               [73:79] "lắm . tóm_lại hài_lòng với sp"  ❌ WRONG
#
# ======================================================================
#   Tong: TP=0 correct, FP=3 wrong, FN=4 missed

# %% [markdown]
# ## 4. Error Analysis

# %%
errors = []
for i, (ts, ps) in enumerate(zip(all_true, all_pred)):
    true_set = set(ts); pred_set = set(ps)
    for label, s, e in true_set - pred_set:
        errors.append({"Text": test_items[i]["text"][:100],
            "Error_Type": f"MISSED: {label} [{s}:{e}]", "Direction": "FN"})
    for label, s, e in pred_set - true_set:
        errors.append({"Text": test_items[i]["text"][:100],
            "Error_Type": f"WRONG: {label} [{s}:{e}]", "Direction": "FP"})

error_df = pd.DataFrame(errors)
print(f"Errors: {len(error_df)} (FN: {(error_df['Direction']=='FN').sum()}, FP: {(error_df['Direction']=='FP').sum()})")
display(error_df.head(15))
plot_error_analysis(error_df, top_n=15)

PIPE_DIR = os.path.join(SAVE_DIR, "pipeline"); os.makedirs(PIPE_DIR, exist_ok=True)
error_df.to_csv(os.path.join(PIPE_DIR, "error_analysis.csv"), index=False)
print(f"\nPipeline Span-F1={span_res['f1']:.4f} | Sent Micro-F1={mt['micro']['f1']:.4f} -> Saved!")
# Out:
# Errors: 8295 (FN: 4556, FP: 3739)
#                                                  Text  \
# 0   mua cho mẹ sài nên củng_không đòi_hỏi gì nhiều...
# 1   mua cho mẹ sài nên củng_không đòi_hỏi gì nhiều...
# 2   mua cho mẹ sài nên củng_không đòi_hỏi gì nhiều...
# 3   mua cho mẹ sài nên củng_không đòi_hỏi gì nhiều...
# 4   mua cho mẹ sài nên củng_không đòi_hỏi gì nhiều...
# 5   mua cho mẹ sài nên củng_không đòi_hỏi gì nhiều...
# 6   máy xài tốt , mượt , sạc rất nhanh , pin trâu ...
# 7   máy xài tốt , mượt , sạc rất nhanh , pin trâu ...
# 8   máy xài tốt , mượt , sạc rất nhanh , pin trâu ...
# 9   máy xài tốt , mượt , sạc rất nhanh , pin trâu ...
# 10  máy xài tốt , mượt , sạc rất nhanh , pin trâu ...
# 11  mình mới mua . mình thấy mẫu đẹp pin trâu cảm_...
# 12  mình mới mua . mình thấy mẫu đẹp pin trâu cảm_...
# 13  mình mới mua . mình thấy mẫu đẹp pin trâu cảm_...
# 14  mình mới mua . mình thấy mẫu đẹp pin trâu cảm_...
#
#                             Error_Type Direction
# 0     MISSED: BATTERY#POSITIVE [18:28]        FN
# 1      MISSED: DESIGN#POSITIVE [10:12]        FN
# 2      MISSED: CAMERA#POSITIVE [11:14]        FN
# 3   WRONG: PERFORMANCE#NEUTRAL [24:28]        FP
# 4      WRONG: BATTERY#POSITIVE [18:24]        FP
# 5       WRONG: DESIGN#POSITIVE [10:14]        FP
# 6      MISSED: BATTERY#POSITIVE [9:12]        FN
# 7       MISSED: BATTERY#POSITIVE [5:9]        FN
# 8      MISSED: CAMERA#POSITIVE [27:32]        FN
# 9       WRONG: CAMERA#POSITIVE [27:33]        FP
# 10      WRONG: BATTERY#POSITIVE [5:27]        FP
# 11       MISSED: DESIGN#POSITIVE [5:8]        FN
# 12   MISSED: FEATURES#POSITIVE [10:12]        FN
# 13    MISSED: SER&ACC#POSITIVE [12:19]        FN
# 14    WRONG: FEATURES#POSITIVE [10:13]        FP
# /kaggle/working/src/utils/visualization.py:118: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=error_counts.values, y=error_counts.index, palette='Reds_r', ax=ax)
# Pipeline Span-F1=0.3716 | Sent Micro-F1=0.7826 -> Saved!
